# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# 1. TikTok 주가 데이터 다운로드
ticker = "TTOO"  # TikTok (티커 코드 예시)
tiktok_data = yf.download(ticker, start="2020-01-01", end="2023-12-31")

# 데이터 확인
print("TikTok 주가 데이터 샘플:\n", tiktok_data.head())

# 2. 연습 문제 예제 생성
# 문제 1: 특정 날짜의 주가 정보 가져오기

print("\n2022-01-03의 데이터:\n", specific_date_data)

# 문제 2: 특정 기간(1년)의 데이터 가져오기

print("\n2021년 TikTok 데이터:\n", one_year_data.head())

# 문제 3: 종가(Close)가 5달러 이상인 날의 데이터 필터링

print("\n종가가 5달러 이상인 데이터:\n", high_price_data.head())

# 문제 4: 거래량(Volume)이 1,000,000 이상인 날의 데이터 필터링

print("\n거래량이 1,000,000 이상인 데이터:\n", high_volume_data.head())

# 문제 5: 특정 기간의 종가 데이터를 시각화
plt.figure(figsize=(12, 6))
plt.plot(one_year_data.index, one_year_data["Close"], label="TikTok Close Price (2021)", color="purple")
plt.title("TikTok Close Prices in 2021")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt


ticker = "TTOO"  # TikTok (티커 코드 예시)
tiktok_data = yf.download(ticker, start="2020-01-01", end="2023-12-31")
print("TikTok 주가 데이터 샘플:\n", tiktok_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# TikTok 주가 데이터 샘플:
#  Price                     Adj Close   Close    High     Low    Open Volume
# Ticker                         TTOO    TTOO    TTOO    TTOO    TTOO   TTOO
# Date
# 2020-01-02 00:00:00+00:00    5800.0  5800.0  6500.0  5650.0  5950.0     72
# 2020-01-03 00:00:00+00:00    6150.0  6150.0  6350.0  5650.0  5700.0     70
# 2020-01-06 00:00:00+00:00    5950.0  5950.0  6200.0  5500.0  6150.0     84
# 2020-01-07 00:00:00+00:00    5950.0  5950.0  6150.0  5800.0  6150.0     45
# 2020-01-08 00:00:00+00:00    5750.0  5750.0  6000.0  5650.0  6000.0     44

# %%
specific_date_data = yf.download(ticker, start="2023-05-15", end="2023-05-16" )
print("\n2023-05-15의 데이터:\n", specific_date_data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2023-05-15의 데이터:
#  Price                     Adj Close Close       High   Low       Open Volume
# Ticker                         TTOO  TTOO       TTOO  TTOO       TTOO   TTOO
# Date
# 2023-05-15 00:00:00+00:00      27.5  27.5  28.799999  26.4  28.799999  13172

# %%
one_year_data = yf.download(ticker, start="2022-01-01", end="2023-01-01" )
print("\n2022년의 데이터:\n", one_year_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2022년의 데이터:
#  Price                     Adj Close   Close    High     Low    Open Volume
# Ticker                         TTOO    TTOO    TTOO    TTOO    TTOO   TTOO
# Date
# 2022-01-03 00:00:00+00:00    2830.0  2830.0  2875.0  2565.0  2565.0    334
# 2022-01-04 00:00:00+00:00    2650.0  2650.0  2830.0  2565.0  2805.0    327
# 2022-01-05 00:00:00+00:00    2500.0  2500.0  2725.0  2465.0  2650.0    253
# 2022-01-06 00:00:00+00:00    2400.0  2400.0  2640.0  2325.0  2450.0    291
# 2022-01-07 00:00:00+00:00    2340.0  2340.0  2450.0  2330.0  2330.0    186

# %%
hp= yf.download(ticker, start="2022-01-01", end="2022-12-31")
high_price_data = hp[hp["Close"]>=5]
print(high_price_data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                     Adj Close   Close         High     Low    Open  \
# Ticker                         TTOO    TTOO         TTOO    TTOO    TTOO
# Date
# 2022-01-03 00:00:00+00:00    2830.0  2830.0  2875.000000  2565.0  2565.0
# 2022-01-04 00:00:00+00:00    2650.0  2650.0  2830.000000  2565.0  2805.0
# 2022-01-05 00:00:00+00:00    2500.0  2500.0  2725.000000  2465.0  2650.0
# 2022-01-06 00:00:00+00:00    2400.0  2400.0  2640.000000  2325.0  2450.0
# 2022-01-07 00:00:00+00:00    2340.0  2340.0  2450.000000  2330.0  2330.0
# ...                             ...     ...          ...     ...     ...
# 2022-12-23 00:00:00+00:00     114.0   114.0   117.400002   113.0   115.0
# 2022-12-27 00:00:00+00:00     106.0   106.0   113.000000   105.0   110.0
# 2022-12-28 00:00:00+00:00     114.0   114.0   127.000000   108.0   115.0
# 2022-12-29 00:00:00+00:00     143.0   143.0   144.000000   115.0   116.0
# 2022-12-30 00:00:00+00:00     142.0   142.0   143.000000   127.0   133.0
#
# Price                     Volume
# Ticker                      TTOO
# Date
# 2022-01-03 00:00:00+00:00    334
# 2022-01-04 00:00:00+00:00    327
# 2022-01-05 00:00:00+00:00    253
# 2022-01-06 00:00:00+00:00    291
# 2022-01-07 00:00:00+00:00    186
# ...                          ...
# 2022-12-23 00:00:00+00:00    687
# 2022-12-27 00:00:00+00:00   1096
# 2022-12-28 00:00:00+00:00   8219
# 2022-12-29 00:00:00+00:00   5616
# 2022-12-30 00:00:00+00:00   2432
#
# [251 rows x 6 columns]

# %%
hv= yf.download(ticker, start="2022-01-01", end="2022-12-31")
high_volume_data = hv[hv["Volume"]>=1000]
print(high_volume_data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                     Adj Close  Close   High    Low   Open  Volume
# Ticker                         TTOO   TTOO   TTOO   TTOO   TTOO    TTOO
# Date
# 2022-01-03 00:00:00+00:00       NaN    NaN    NaN    NaN    NaN     NaN
# 2022-01-04 00:00:00+00:00       NaN    NaN    NaN    NaN    NaN     NaN
# 2022-01-05 00:00:00+00:00       NaN    NaN    NaN    NaN    NaN     NaN
# 2022-01-06 00:00:00+00:00       NaN    NaN    NaN    NaN    NaN     NaN
# 2022-01-07 00:00:00+00:00       NaN    NaN    NaN    NaN    NaN     NaN
# ...                             ...    ...    ...    ...    ...     ...
# 2022-12-23 00:00:00+00:00       NaN    NaN    NaN    NaN    NaN     NaN
# 2022-12-27 00:00:00+00:00     106.0  106.0  113.0  105.0  110.0  1096.0
# 2022-12-28 00:00:00+00:00     114.0  114.0  127.0  108.0  115.0  8219.0
# 2022-12-29 00:00:00+00:00     143.0  143.0  144.0  115.0  116.0  5616.0
# 2022-12-30 00:00:00+00:00     142.0  142.0  143.0  127.0  133.0  2432.0
#
# [251 rows x 6 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(one_year_data.index, one_year_data["Close"], label="TikTok Close Price (2022)", color="purple")
plt.title("TikTok Close Prices in 2022")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 연습 문제 제안
# 문제 1: 특정 날짜의 데이터 가져오기
# python
#
# 문제 2: 특정 기간의 데이터 가져오기
# python
# print("\n2022년의 데이터:\n", year_data)
# # 질문: 2022년 전체 데이터만 추출하세요.
#
# 문제 3: 조건에 맞는 데이터 필터링
# python
# 코드 복사
# # 질문: 종가가 2달러 이하인 날의 데이터를 추출하세요.
#
# 문제 4: 거래량이 많은 날 분석
# python
# 코드 복사
# # 질문: 거래량이 2백만 이상인 데이터를 추출하고, 해당 데이터의 평균 종가를 계산하세요.
#
#
# 문제 5: 시각화
# python
# 코드 복사
# # 질문: 2021년 데이터를 사용하여 종가(Close)와 거래량(Volume)의 트렌드를 시각화하세요.
# plt.figure(figsize=(12, 6))
# plt.plot(one_year_data.index, one_year_data["Close"], label="Close Price", color="blue")
# plt.bar(one_year_data.index, one_year_data["Volume"], label="Volume", color="orange", alpha=0.5)
# plt.title("TikTok Stock Close Price and Volume in 2021")
# plt.xlabel("Date")
# plt.ylabel("Value")
# plt.legend()
# plt.show()
# 필요 라이브러리 설치
# 아래 명령어를 사용해 필요한 라이브러리를 설치하세요:
#
# bash
# 코드 복사
# pip install yfinance pandas matplotlib
